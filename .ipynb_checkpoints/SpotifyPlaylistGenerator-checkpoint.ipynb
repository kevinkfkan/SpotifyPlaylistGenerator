# %% [markdown]
# # <div align="center">Personalized Spotify Playlist Recommendations</div>

# %% [markdown]
# ## 1. Introduction
# ***

# %% [markdown]
# ### 1.1 What This Notebook Does
# ***
#
# Spotify allows users to make their own custom playlists. While Spotify already has a system implemented for playlist track recommendations, this notebook allows for more personalized playlist recommendations that take into account how well the user thinks certain tracks fit into the playlist as well as the user's tastes in music.

# %% [markdown]
# ### 1.2 How This Notebook Works
# ***
#
# This project is coded in Python 3 along with several data science and machine learning libraries listed below. If you are here from my GitHub, you can see all the dependencies I've used. This project was created in a PIP environemnt and the .piplock file is given in the repository.
#
# To start, Spotify for Developers was used to create an app to provide client credentials. Using the Spotipy python library and Spotify API, user playlists are extracted and acoustic features of each track are provided. Each track from the playlist can provide up to twenty track recommendations using the API. Using machine learning, the user playlist's and recommended tracks' acoustic features were used to provide a sense of which recommended tracks fit best into the playlist. The best of the recommeded tracks are put into a seperate playlist for the user.

# %% [markdown]
# ## 2. Walkthrough of the Code
# ***

# %% [markdown]
# ### 2.1 Libraries
# ***

# %%
# Spotipy / Spotify API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# Data Analytics
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn import decomposition
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Other
from functools import reduce
import warnings

# %% [markdown]
# ### 2.2 Setting Up Spotify Client Credentials
# ***
#
# Using **_Spotify for Developers_** a Spotify web application was created. Client credentials can be found on the web app.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

cid = '362ab65e27f44f56b2bd2b2f62987e12'
secret = '3a3c7171323649d0a3f3e2b8e57283ab'
username = 'maelstromcarnage'

scope = 'user-top-read user-library-read playlist-modify-public playlist-read-private'

redirect_uri='http://localhost:8080/callback/'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

token = util.prompt_for_user_token(username, scope, cid, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
# df_topfifty_features.hist(figsize=(40,30))
# plt.show()

# %%
# sns.pairplot(df_topfifty_features)

# %% [markdown]
# ### 2.3 Extracting User Playlists
# ***

# %%
def user_playlist(username):
    playlist_id = []
    playlist_name = []
    num_tracks = []
    
    featured = sp.user_playlists(username)
    for i, items in enumerate(featured['items']):
        playlist_id.append(items['id'])
        playlist_name.append(items['name'])
        num_tracks.append(items['tracks']['total'])
        
    df_your_lib = pd.DataFrame({'Playlist IDs': playlist_id, 'Playlist Name': playlist_name, '# Tracks': num_tracks})
    
    return df_your_lib

# %%
df_user_playlists = user_playlist(username)
df_user_playlists = df_user_playlists[~df_user_playlists['Playlist Name']
                                      .str
                                      .contains('|'.join(['Custom', 'Discover']))]

# Removing playlists with less than 30 songs
df_user_playlists.drop(df_user_playlists[df_user_playlists['# Tracks']<30]
                      .index
                      , inplace = True)

df_user_playlists
# Out:
#               Playlist IDs                                   Playlist Name  \
# 2   37i9dQZF1Etqmy3cR2SQKX                             Your Top Songs 2019
# 3   4GwcudpBXsbCmI9N6uKCJA        playlist thats definitely made by 39daph
# 4   7429Z8tLqdozs9XR5TH2W0                                      Jazz Beats
# 5   3vJqJqOIyPDkX3gWfNCJbS                       Sleep/Lofi/Chill Playlist
# 6   37i9dQZF1DX5g856aiKiDS                                     Dalkom Cafe
# 9   1kLp8FXc4tidYIRwA5qjTY                                   Studio Ghibli
# 10  1xY6msLHX1W34EzB0UkkbU  Guardians of the Galaxy – The Complete Mixtape
# 12  37i9dQZF1DWWwaxRea1LWS                              Throwback Thursday
# 13  5B0iYhG3tY3EXKCiYKtjxW                                Alternative Rock
# 15  3j1yvDP45Gsv0Y3tfDT5MC                                Liked from Radio
#
#     # Tracks
# 2        100
# 3       1208
# 4        256
# 5        698
# 6         50
# 9        246
# 10        52
# 12        50
# ...

# %% [markdown]
# ### 2.4 Choosing A Playlist and Extracting Its Tracks
# ***

# %% [markdown]
# #### 2.4.1 Playlist Audio Means
# Out of curiosity, lets see how the means audio feature means of each playlist compare with one another.

# %%
def get_playlist_tracks(username, sourcePlaylistID):
    
    sourcePlaylist = sp.user_playlist(username, sourcePlaylistID)
    tracks = sourcePlaylist['tracks']
    songs = tracks['items']
    
    track_ids = []
    track_names = []
    
    for i in range(0, len(songs)):
        # Ensuring local tracks are not included (no data on tracks)
        if songs[i]['track']['id'] != None:
            track_ids.append(songs[i]['track']['id'])
            track_names.append(songs[i]['track']['name'])

    features = []
    for i in range(0, len(track_ids)):
        audio_features = sp.audio_features(track_ids[i])
        for track in audio_features:
            features.append(track)
    
    playlist_df = pd.DataFrame(features, index=track_names)
    
    # Returning only features that are needed
    return playlist_df[['id', 'acousticness', 'danceability', 
                        'energy', 'instrumentalness', 
                        'key', 'liveness', 'loudness', 'mode', 
                        'speechiness', 'tempo', 'valence']]

# %%
def mean_audio_features(playlist_id):
    playlist_audio_features = get_playlist_tracks(username, playlist_id)
    return pd.DataFrame(playlist_audio_features.mean(),columns=[playlist_id])

# %%
user_playlists_features = []

for ids in df_user_playlists['Playlist IDs']:
    user_playlists_features.append(mean_audio_features(ids))
    
df_user_playlists_feat = reduce(lambda left, right: pd.merge(left,right, left_index=True, right_index=True), user_playlists_features)
df_user_playlists_feat
# Out:
#                   37i9dQZF1Etqmy3cR2SQKX  4GwcudpBXsbCmI9N6uKCJA  \
# acousticness                    0.346001                0.441738
# danceability                    0.619010                0.666680
# energy                          0.547595                0.493740
# instrumentalness                0.154603                0.049592
# key                             5.560000                5.290000
# liveness                        0.189125                0.182684
# loudness                       -9.584010               -8.718860
# mode                            0.590000                0.610000
# speechiness                     0.121716                0.107282
# tempo                         117.187820              109.832880
# valence                         0.432424                0.434896
#
#                   7429Z8tLqdozs9XR5TH2W0  3vJqJqOIyPDkX3gWfNCJbS  \
# acousticness                    0.245897                0.626588
# ...

# %% [markdown]
# #### 2.4.2 Selecting A Playlist
# ***

# %% [markdown]
# In section 2.3, I've listed my own playlists that I have on Spotify. For this project, I chose to find track recommendations for the Dalkom Cafe playlist for the following reasons:
# * I like the playlist :)
# * It has a good number of songs for this project (50 songs)
#     * A playlist with more songs will help with the machine learning part later but I want to be able to load this notebook fast

# %%
playlist_tracks_df = get_playlist_tracks(username, '37i9dQZF1DX5g856aiKiDS')
playlist_tracks_df.head()
# Out:
#                                                        id  acousticness  \
# My Lips Like Warm Coffee           7j59Opz7qhb2aj7cnu7iLr         0.749
# Kangaroo                           1Oi9J5OpJmnZusVBbt2cjo         0.832
# I wanna go out                     75C9zW7Liktu6ULymEuL2y         0.750
# Can I Love ? (feat. youra, Meego)  4T2cOfemKB0owJS2JOu7dF         0.555
# say what's on your mind            5sZOGj6SfzD7lWpwKhF6oE         0.810
#
#                                    danceability  energy  instrumentalness  \
# My Lips Like Warm Coffee                  0.691   0.709          0.000042
# Kangaroo                                  0.802   0.346          0.000004
# I wanna go out                            0.587   0.440          0.000000
# Can I Love ? (feat. youra, Meego)         0.708   0.441          0.000005
# say what's on your mind                   0.676   0.462          0.028600
#
#                                    key  liveness  loudness  mode  speechiness  \
# ...

# %%
# Showing frequency of acoustic features in tracks

playlist_tracks_df.hist(figsize=(10,10), grid=False) 
plt.tight_layout()
plt.show()

# %%
mean_audio_features('37i9dQZF1DX5g856aiKiDS')
# Out:
#                   37i9dQZF1DX5g856aiKiDS
# acousticness                    0.566572
# danceability                    0.652400
# energy                          0.544060
# instrumentalness                0.041080
# key                             5.280000
# liveness                        0.189270
# loudness                       -6.635900
# mode                            0.600000
# speechiness                     0.090108
# tempo                         103.789740
# valence                         0.459808

# %% [markdown]
# #### 2.4.3 Getting Spotify Recommendations for Machine Learning
# ***

# %% [markdown]
# We will be using machine learning to select the best tracks from a list of tracks that spotify recommends. Spotify can recommend up to 20 songs for every track in the user selected playlist. However I am limiting the number of recommended tracks per playlist track to 5 to save time.
#
# From the recommended songs, the best tracks that fit into the playlist will be selected for recommendation to the playlist using machine learning.

# %%
def get_recommendations(tracks):
    recommendations = []
    for x in tracks:
        # Spotify sometimes has songs unavailable which we can't get recommendations for
        try:
            data = sp.recommendations(seed_tracks=[x], limit=10) # Increase the limit for more/better recommendations
            recommendations.extend(data['tracks'])
        except:
            pass
    return recommendations

# %%
recommendations = get_recommendations(playlist_tracks_df['id'])
recommendations_df = pd.DataFrame(recommendations)
recommendations_df.head()
# Out:
#                                                album  \
# 0  {'album_type': 'SINGLE', 'artists': [{'externa...
# 1  {'album_type': 'SINGLE', 'artists': [{'externa...
# 2  {'album_type': 'SINGLE', 'artists': [{'externa...
# 3  {'album_type': 'ALBUM', 'artists': [{'external...
# 4  {'album_type': 'SINGLE', 'artists': [{'externa...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ...

# %% [markdown]
# #### 2.4.4 Getting Acoustic Features for Recommended Tracks
# ***
#
# Now that the recommended tracks are provided, the acoustic features are obtained and put into a dataframe for legibility.

# %%
def get_audio_features_df(df):
    
    features = []
    track_id = []
    
    for song_id in df['id']:
        audio_features = sp.audio_features(song_id)
        for track in audio_features:
            features.append(track)
    
    playlist_df = pd.DataFrame(features)
    
    # Returning only features that are needed
    return playlist_df[['id', 'acousticness', 'danceability', 
                        'energy', 'instrumentalness', 
                        'key', 'liveness', 'loudness', 'mode', 
                        'speechiness', 'tempo', 'valence']]

# %%
recommendations_df = get_audio_features_df(recommendations_df)
recommendations_df
# Out:
#                          id  acousticness  danceability  energy  \
# 0    3uZA0ESQMYXlOb7bXHwlfd         0.416         0.784   0.554
# 1    4AHNi316rl3KI3hKIsdxZe         0.382         0.575   0.607
# 2    0JL7DoEqAUcOntWmBuOSdh         0.724         0.588   0.452
# 3    2TyDgN8q5NgOuiR8yYyBYj         0.529         0.555   0.705
# 4    3ZsDedN6LsO0jyfE8Re494         0.179         0.759   0.850
# ..                      ...           ...           ...     ...
# 485  6WdWUIfP8zAhkzdmknWjTd         0.594         0.856   0.352
# 486  1EGtfMlDM9qOb0C0vQYz8H         0.239         0.724   0.492
# 487  63zyClEFJbDG9RoRtGHi9c         0.807         0.656   0.686
# 488  3MEcq4JRbQImU04hBtyM0w         0.740         0.788   0.577
# 489  3uvZ3byiImZKagTxZpHlZN         0.795         0.729   0.330
#
#      instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0            0.000000    0    0.2160    -7.255     1       0.2960   97.161
# ...

# %% [markdown]
# ### 2.5 Machine Learning
# ***

# %% [markdown]
# #### 2.5.1 Features and Labels
#
# To begin training the data set, each track in the user playlist is given a rating from 1 to 10 on how well the user thinks the track fits into the playlist.

# %%
playlist_tracks_df['ratings'] = [10, 6, 7, 7, 8, 9, 8, 9, 4, 9,
                                4, 6, 10, 9, 7, 4, 10, 7, 8, 10,
                                6, 5, 8, 9, 4, 7, 7, 4, 4, 6,
                                8, 7, 4, 4, 6, 6, 6, 6, 8, 5,
                                5, 7, 7, 8, 9, 8, 7, 8, 9, 8]

playlist_tracks_df.head()
# Out:
#                                                        id  acousticness  \
# My Lips Like Warm Coffee           7j59Opz7qhb2aj7cnu7iLr         0.749
# Kangaroo                           1Oi9J5OpJmnZusVBbt2cjo         0.832
# I wanna go out                     75C9zW7Liktu6ULymEuL2y         0.750
# Can I Love ? (feat. youra, Meego)  4T2cOfemKB0owJS2JOu7dF         0.555
# say what's on your mind            5sZOGj6SfzD7lWpwKhF6oE         0.810
#
#                                    danceability  energy  instrumentalness  \
# My Lips Like Warm Coffee                  0.691   0.709          0.000042
# Kangaroo                                  0.802   0.346          0.000004
# I wanna go out                            0.587   0.440          0.000000
# Can I Love ? (feat. youra, Meego)         0.708   0.441          0.000005
# say what's on your mind                   0.676   0.462          0.028600
#
#                                    key  liveness  loudness  mode  speechiness  \
# ...

# %% [markdown]
# #### 2.5.2 t-distributed Stochastic Neighbor Embedding (TSNE)
# ***

# %%
X_train = playlist_tracks_df.drop(['id', 'ratings', 'mode'], axis=1)
y_train = playlist_tracks_df['ratings']

X_scaled = StandardScaler().fit_transform(X_train)

# %%
import warnings
warnings.filterwarnings('ignore')

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=88)

tsne = TSNE(random_state=88)

X_tsne = tsne.fit_transform(X_scaled)
X_tsne.shape
# Out:
# (50, 2)

# %% [markdown]
# #### 2.5.3 Training Random Forest Classifier
# ***

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=88, 
                             n_jobs=-1, oob_score=True)
rfc_param = {'max_features': [1, 2, 3],
             'min_samples_leaf': [1, 3, 5, 8],
             'max_depth': [3, 4, 5, 8, 12, 16, 20]
            }

rfc_gcv = GridSearchCV(rfc, rfc_param, n_jobs=-1, cv=skf, verbose=1)
rfc_gcv.fit(X_tsne, y_train)

rfc_gcv.best_estimator_, rfc_gcv.best_score_
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# (RandomForestClassifier(max_depth=3, max_features=2, n_jobs=-1, oob_score=True,
#                         random_state=88),
#  0.32)

# %% [markdown]
# #### 2.5.4 Training k-Nearest Neighbor
# ***

# %%
knn_param = {'n_neighbors': range(1, 10)}
knn = KNeighborsClassifier(n_jobs=-1)

knn_gcv = GridSearchCV(knn, knn_param, cv=skf, n_jobs=-1, verbose=True)
knn_gcv.fit(X_tsne, y_train)

knn_gcv.best_params_, knn_gcv.best_score_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ({'n_neighbors': 7}, 0.24)

# %% [markdown]
# ####  2.5.5 Making Predictions using a Model
# ***

# %% [markdown]
# From the GridSearchCV cross-validation scores in sections 2.5.3 and 2.5.4, the Random Forest Classifier seems to be a better model to predict the data and therefore it is used instead of the k-Nearest Neighbor model.

# %%
rec_df = recommendations_df.set_index('id').drop(['mode'], axis=1)

rfc_gcv.best_estimator_.fit(X_tsne, y_train)
rec_df_scaled = StandardScaler().fit_transform(rec_df)
rec_df_scaled_tsne = tsne.fit_transform(rec_df_scaled)
y_pred = rfc_gcv.best_estimator_.predict(rec_df_scaled_tsne)

rec_df['ratings'] = y_pred
rec_df = rec_df.sort_values('ratings', ascending=False).reset_index()

rec_to_add = rec_df[rec_df['ratings']>=8]['id'].values.tolist()

# %% [markdown]
# ## 3. Creating the ML Recommended Tracks Playlist
# ***

# %% [markdown]
# Removing duplicates and using the Spotify API to create a playlist of the ML recommended tracks for the playlist.

# %%
def remove_list_duplicates(input_list):
    output_list = []
    [output_list.append(x) for x in input_list if x not in output_list]
    return output_list

# %%
rec_to_add = remove_list_duplicates(rec_to_add)
ml_playlist = sp.user_playlist_create(user=username, name='Recommendations for Playlist',  description = 'Machine Learning Recommended Tracks')
# Spotify API can only add 100 tracks at a time
sp.user_playlist_add_tracks(username, ml_playlist['id'], rec_to_add[0:99])
# Out:
# {'snapshot_id': 'MyxkZGFjZTNmZTJlMmE0ZGQyY2ZhNDMwYzQ0NTU2MTdlNDhmZTk5Njc3'}
